# %%
import pandas as pd
from pandasql import sqldf
pysqldf = lambda q: sqldf(q, globals())

# %%
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('iaMetadataVideos/iaMetadataVideos2.csv')

# %%
df
# Out:
#             ID        _originalFilesIA            addeddate backup_location  \
# 0     ffbn0006            csx27a00.mp4  2014-06-05 23:21:39     ia905808_25
# 1     ffcn0006    tobacco_yby27a00.mp4  2015-06-04 04:59:24     ia905306_18
# 2     ffcw0111          2049009058.mpg  2009-03-20 01:18:16     ia903602_32
# 3     ffdn0006  tobacco_uly27a00.mpeg4  2011-09-02 16:36:46     ia903702_30
# 4     fffc0072    Bates_2073732766.mpg  2008-04-03 23:03:20     ia903601_29
# ...        ...                     ...                  ...             ...
# 5307  zzvn0006            bsx27a00.mp4  2014-06-05 23:05:45     ia905808_25
# 5308  zzwc0072  tobacco_ioy27a00.mpeg4  2011-09-02 16:55:19     ia903702_30
# 5309  zzww0111    tobacco_bbg12a00.mpg  2018-06-05 16:52:49     ia906706_13
# 5310  zzyd0111            VTS_01_1.mpg  2006-03-01 19:22:07     ia903600_13
# 5311  zzym0006  tobacco_jyw27a00.mpeg4  2011-09-01 15:28:00     ia903702_29
#
# ...

# %%
pysqldf("SELECT COUNT(*) FROM df WHERE description IS NULL")
# Out:
#    COUNT(*)
# 0       706

# %%
pysqldf("SELECT description, subject FROM df WHERE subject IS NULL")
# Out:
#                                          description subject
# 0  Footage of various Philip Morris sponsored aut...    None
# 1                                               None    None

# %%
pysqldf("SELECT COUNT(*) FROM df WHERE title IS NULL")
# Out:
#    COUNT(*)
# 0         0

# %%
pysqldf("SELECT description, subject FROM df WHERE LOWER(subject) LIKE '%deposition%'")

# %%
# add a column for google AutoML's suggested categories?
# AutoML may do this as well
# ChatGPT to do a summary (or similar technology)
# Junior interns can check on accuracy
# Could we do a bluscore to check the similarity of manually enhanced documents vs machine generated data
# add column for an automated description
# columns for automated topics - one for generally trained model (autoML or similar), one for custom trained model

# %%
# how many of these do we already have transcripts for? 
# cross reference with the 1000 that have already been translated.

# %%
# get the ids of the 1000 that are already generated

# %%
df.head()
