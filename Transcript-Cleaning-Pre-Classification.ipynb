# %%
import pandas as pd
import re
from pandasql import sqldf
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import precision_recall_fscore_support
from sklearn.metrics import precision_recall_curve
from sklearn.model_selection import cross_val_score
import nltk
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from nltk.stem import WordNetLemmatizer

# %%
pd.set_option('display.max_colwidth', 70)
pd.set_option('display.max_rows', None)
pysqldf = lambda q: sqldf(q, globals())

# %%
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/noelsalmeron/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/noelsalmeron/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
# setting a couple of workbook variables
text_source = "transcript"
tag = "lawsuit"

# text cleaning variables
stop = stopwords.words('english')
lemmatizer = WordNetLemmatizer()

# %%
df_human = pd.read_csv("data/classifications.csv")
df_ml = pd.read_csv("data/transcript_accuracy.csv")

# %%
df_dataset = pysqldf(f"""
SELECT dh.*, dml.{text_source}
FROM 
    df_human dh
JOIN
    df_ml dml
ON dh.ID = dml.id
    WHERE description is not NULL
    AND description != 'error code 224003'
""")

# %%
len(df_dataset)
# Out:
# 341

# %%
# lowercase using for loop and new array
#transcript_col = df_dataset['transcript']
#transcripts = []
#for t in transcript_col:
#    transcripts.append(t.lower())
    
# lowercase using apply
df_dataset['transcript'] = df_dataset['transcript'].apply(str.lower, 'transcript')

#df_dataset.head()

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/noelsalmeron/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# using list of stop words from NLTK library 
# + p.m. and a.m. which commonly show up in transcripts
stop_words = stopwords.words('english') + ['we\'re', 'p.m.,', 'a.m.', 'okay', 'yes']
#print(stop_words)

def remove_stop_words(str):
    new_str = ''
    for word in str.split(): 
        if word not in stop_words:
            new_str = new_str + word + ' '
    return new_str[:-1] # removes last space

#remove_stop_words('This is a sentence.')

df_dataset['transcript'] = df_dataset['transcript'].apply(remove_stop_words, 'transcript')
df_dataset.head(5)
# Out:
#          ID  \
# 0  ffxh0257
# 1  fghb0039
# 2  fgxh0257
# 3  fhfk0146
# 4  fhgb0191
#
#                                                              description  \
# 0  Deposition of Jeff Kilper in RE: National Prescription Opiate Liti...
# 1  Camel Cigarettes infomercial on why their cigarettes are superior ...
# 2  Deposition of Mark Trudeau in Re: State of Rhode Island v Purdue P...
# 3  CNN debate on the ban of smoking on Airplanes. Ban is put in place...
# 4                  Compilation of ads for children to say no to smoking.
#
#                                                             subject  \
# 0  lawsuit; legal activity; litigation; opioids; sales; marketing;
# 1                                    tobacco; cigarette; marketing;
# 2  lawsuit; legal activity; litigation; opioids; sales; marketing;
# 3          tobacco; cigarette;secondhand smoke; closed environment;
# 4          tobacco; cigarette; youth access; PSA; children; future;
#
#                                                                    title  \
# 0  Deposition of Jeff Kilper, Senior Director for Finance for Special...
# 1                                          Camel Cigarettes informercial
# 2                          Deposition of Mark Trudeau, President and CEO
# 3                              CNN Crossfire debate on smoking in public
# 4                            Think. Don't Smoke. ad campaign compilation
#
#     runtime  \
# 0   1:07:17
# 1  00:20:51
# 2   0:52:40
# 3   0:26:20
# 4   0:34:02
#
#                                                               transcript
# 0  record 12:49 took lunch break mrs. dilber talking exhibit number 9...
# 1  getting pretty late hit trail snoop around living like ain't 9 5 j...
# 2  back record 551 questions witness concludes mr. trudeau compositio...
# 3  tonight washington crossfire saturday smoking skies ifs ands butts...
# 4  hey guys may ask couple questions ever tried cigarettes know reall...

# %%
# remove everything that isn't alphanumeric
def alphabetic(str):
    return re.sub(r'[^a-zA-Z]+', ' ', str)

# alphabetic("hey 3there00 bud 129.129")

df_dataset['transcript'] = df_dataset['transcript'].apply(alphabetic, 'transcript')
df_dataset.head()
# Out:
#          ID  \
# 0  ffxh0257
# 1  fghb0039
# 2  fgxh0257
# 3  fhfk0146
# 4  fhgb0191
#
#                                                              description  \
# 0  Deposition of Jeff Kilper in RE: National Prescription Opiate Liti...
# 1  Camel Cigarettes infomercial on why their cigarettes are superior ...
# 2  Deposition of Mark Trudeau in Re: State of Rhode Island v Purdue P...
# 3  CNN debate on the ban of smoking on Airplanes. Ban is put in place...
# 4                  Compilation of ads for children to say no to smoking.
#
#                                                             subject  \
# 0  lawsuit; legal activity; litigation; opioids; sales; marketing;
# 1                                    tobacco; cigarette; marketing;
# 2  lawsuit; legal activity; litigation; opioids; sales; marketing;
# 3          tobacco; cigarette;secondhand smoke; closed environment;
# 4          tobacco; cigarette; youth access; PSA; children; future;
#
#                                                                    title  \
# 0  Deposition of Jeff Kilper, Senior Director for Finance for Special...
# 1                                          Camel Cigarettes informercial
# 2                          Deposition of Mark Trudeau, President and CEO
# 3                              CNN Crossfire debate on smoking in public
# 4                            Think. Don't Smoke. ad campaign compilation
#
#     runtime  \
# 0   1:07:17
# 1  00:20:51
# 2   0:52:40
# 3   0:26:20
# 4   0:34:02
#
#                                                               transcript
# 0  record took lunch break mrs dilber talking exhibit number page num...
# 1  getting pretty late hit trail snoop around living like ain t job k...
# 2  back record questions witness concludes mr trudeau composition tha...
# 3  tonight washington crossfire saturday smoking skies ifs ands butts...
# 4  hey guys may ask couple questions ever tried cigarettes know reall...

# %%
# columns for stem and lemmatizing
stemmer = PorterStemmer()
def stem(str):
    new_str = ''
    for word in str.split():
        new_str += stemmer.stem(word) + ' '
    return new_str

df_dataset['stemmed'] = df_dataset['transcript'].apply(stem, 'transcript')
df_dataset.head()
# Out:
#          ID  \
# 0  ffxh0257
# 1  fghb0039
# 2  fgxh0257
# 3  fhfk0146
# 4  fhgb0191
#
#                                                              description  \
# 0  Deposition of Jeff Kilper in RE: National Prescription Opiate Liti...
# 1  Camel Cigarettes infomercial on why their cigarettes are superior ...
# 2  Deposition of Mark Trudeau in Re: State of Rhode Island v Purdue P...
# 3  CNN debate on the ban of smoking on Airplanes. Ban is put in place...
# 4                  Compilation of ads for children to say no to smoking.
#
#                                                             subject  \
# 0  lawsuit; legal activity; litigation; opioids; sales; marketing;
# 1                                    tobacco; cigarette; marketing;
# 2  lawsuit; legal activity; litigation; opioids; sales; marketing;
# 3          tobacco; cigarette;secondhand smoke; closed environment;
# 4          tobacco; cigarette; youth access; PSA; children; future;
#
#                                                                    title  \
# 0  Deposition of Jeff Kilper, Senior Director for Finance for Special...
# 1                                          Camel Cigarettes informercial
# 2                          Deposition of Mark Trudeau, President and CEO
# 3                              CNN Crossfire debate on smoking in public
# 4                            Think. Don't Smoke. ad campaign compilation
#
#     runtime  \
# 0   1:07:17
# 1  00:20:51
# 2   0:52:40
# 3   0:26:20
# 4   0:34:02
#
#                                                               transcript  \
# 0  record took lunch break mrs dilber talking exhibit number page num...
# 1  getting pretty late hit trail snoop around living like ain t job k...
# 2  back record questions witness concludes mr trudeau composition tha...
# 3  tonight washington crossfire saturday smoking skies ifs ands butts...
# 4  hey guys may ask couple questions ever tried cigarettes know reall...
#
#                                                                  stemmed
# 0  record took lunch break mr dilber talk exhibit number page number ...
# 1  get pretti late hit trail snoop around live like ain t job knew ki...
# 2  back record question wit conclud mr trudeau composit thank sir tha...
# 3  tonight washington crossfir saturday smoke sky if and butt left pa...
# 4  hey guy may ask coupl question ever tri cigarett know realli much ...

# %%
# remove one or two character pairs
def character_clean(str):
    new_str = ''
    for word in str.split():
        if len(word) > 2:
            new_str += word + ' '
    return new_str

# character_clean('This is a sentence')
df_dataset['transcript'] = df_dataset['transcript'].apply(character_clean, 'transcript')
df_dataset['stemmed'] = df_dataset['stemmed'].apply(character_clean, 'stemmed')
df_dataset.head()
# Out:
#          ID  \
# 0  ffxh0257
# 1  fghb0039
# 2  fgxh0257
# 3  fhfk0146
# 4  fhgb0191
#
#                                                              description  \
# 0  Deposition of Jeff Kilper in RE: National Prescription Opiate Liti...
# 1  Camel Cigarettes infomercial on why their cigarettes are superior ...
# 2  Deposition of Mark Trudeau in Re: State of Rhode Island v Purdue P...
# 3  CNN debate on the ban of smoking on Airplanes. Ban is put in place...
# 4                  Compilation of ads for children to say no to smoking.
#
#                                                             subject  \
# 0  lawsuit; legal activity; litigation; opioids; sales; marketing;
# 1                                    tobacco; cigarette; marketing;
# 2  lawsuit; legal activity; litigation; opioids; sales; marketing;
# 3          tobacco; cigarette;secondhand smoke; closed environment;
# 4          tobacco; cigarette; youth access; PSA; children; future;
#
#                                                                    title  \
# 0  Deposition of Jeff Kilper, Senior Director for Finance for Special...
# 1                                          Camel Cigarettes informercial
# 2                          Deposition of Mark Trudeau, President and CEO
# 3                              CNN Crossfire debate on smoking in public
# 4                            Think. Don't Smoke. ad campaign compilation
#
#     runtime  \
# 0   1:07:17
# 1  00:20:51
# 2   0:52:40
# 3   0:26:20
# 4   0:34:02
#
#                                                               transcript  \
# 0  record took lunch break mrs dilber talking exhibit number page num...
# 1  getting pretty late hit trail snoop around living like ain job kne...
# 2  back record questions witness concludes trudeau composition thank ...
# 3  tonight washington crossfire saturday smoking skies ifs ands butts...
# 4  hey guys may ask couple questions ever tried cigarettes know reall...
#
#                                                                  stemmed
# 0  record took lunch break dilber talk exhibit number page number cou...
# 1  get pretti late hit trail snoop around live like ain job knew kind...
# 2  back record question wit conclud trudeau composit thank sir thank ...
# 3  tonight washington crossfir saturday smoke sky and butt left part ...
# 4  hey guy may ask coupl question ever tri cigarett know realli much ...

# %%
df_dataset = df_dataset.drop(['description', 'subject'], axis=1)
df_dataset.head(10)
# Out:
#          ID  \
# 0  ffxh0257
# 1  fghb0039
# 2  fgxh0257
# 3  fhfk0146
# 4  fhgb0191
# 5  fhhb0039
# 6  fhhh0100
# 7  fhhj0223
# 8  fhwm0256
# 9  fjhb0039
#
#                                                                    title  \
# 0  Deposition of Jeff Kilper, Senior Director for Finance for Special...
# 1                                          Camel Cigarettes informercial
# 2                          Deposition of Mark Trudeau, President and CEO
# 3                              CNN Crossfire debate on smoking in public
# 4                            Think. Don't Smoke. ad campaign compilation
# 5                      RJ Reynolds Tobacco board meeting on advertisment
# 6                               Camel cigarette advertisment compilation
# 7                                              ABC 7 news report: WeCard
# 8                                             Opiod prescriber interview
# 9                                           Winston No Bull comedy break
#
#     runtime  \
# 0   1:07:17
# 1  00:20:51
# 2   0:52:40
# 3   0:26:20
# 4   0:34:02
# 5   0:15:07
# 6   0:27:35
# 7   0:09:08
# 8   0:01:35
# 9   0:17:38
#
#                                                               transcript  \
# 0  record took lunch break mrs dilber talking exhibit number page num...
# 1  getting pretty late hit trail snoop around living like ain job kne...
# 2  back record questions witness concludes trudeau composition thank ...
# 3  tonight washington crossfire saturday smoking skies ifs ands butts...
# 4  hey guys may ask couple questions ever tried cigarettes know reall...
# 5  hello doug sarah mcclurkin think time program talked know one ciga...
# 6  ever heard man literally walk wall human fly well looking hundred ...
# 7  top story tonight indiana retail associations joining forces keep ...
# 8  tell remember detail happened iraq benefits drug used force rememb...
# 9  welcome winston bull comedy break guys gonna right watching gerald...
#
#                                                                  stemmed
# 0  record took lunch break dilber talk exhibit number page number cou...
# 1  get pretti late hit trail snoop around live like ain job knew kind...
# 2  back record question wit conclud trudeau composit thank sir thank ...
# 3  tonight washington crossfir saturday smoke sky and butt left part ...
# 4  hey guy may ask coupl question ever tri cigarett know realli much ...
# 5  hello doug sarah mcclurkin think time program talk know one cigare...
# 6  ever heard man liter walk wall human fli well look hundr feet mari...
# 7  top stori tonight indiana retail associ join forc keep tobacco rea...
# 8  tell rememb detail happen iraq benefit drug use forc rememb stuff ...
# 9  welcom winston bull comedi break guy gonna right watch geraldo com...

# %%
df_dataset.to_csv('data/cleaned_data.csv', index=False)
